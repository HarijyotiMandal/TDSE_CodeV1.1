# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.linalg import expm, eigh
import os
# %matplotlib widget

# Atomic Unit Conversion
au_time = 2.4188843265864e-2 # fs
hartree_energy = 27.211386245981 # eV
au_time_conversion = 1 / au_time # from fs to au_time
au_energy_conversion = 1 / hartree_energy # from eV to au_energy

os.chdir('/asap3/flash/gpfs/fl26/2023/data/11015602/shared/Harijyoti/')
os.getcwd()

def C_t(t, t_min, t_max, delta_T):
    return np.where(
        t < t_min - delta_T, 0,
        np.where(t < t_min, np.sin((t - (t_min - delta_T)) * (np.pi / (2 * delta_T))) ** 2,
        np.where(t <= t_max, 1,
        np.where(t <= t_max + delta_T, np.cos((t - t_max) * (np.pi / (2 * delta_T))) ** 2, 0))))

# Function for E_omega (fundamental frequency)
def E_omega(t, E0, omega, t0, tau, phi_w):
    envelope = np.exp(-((t - t0) / tau) ** 2)
    oscillation_w = np.cos(omega * t + phi_w)
    return (E0 * envelope * oscillation_w )* C_t(t, t_min, t_max, delta_T)

# %%
# Define energy levels (in eV)
energy_levels = {
    '1s': -24.6,
    '1s2p': -3.4,
    's': 17.8,
    'p': 17.8,
    'd': 17.8
}



# Energies and dipole elements
omega_s_eV = energy_levels['1s']
omega_p_eV = energy_levels['1s2p']
omega_es_eV = energy_levels['s']
omega_ep_eV = energy_levels['p']
omega_ed_eV = energy_levels['d']

# Convert energies from eV to atomic units
omega_s = omega_s_eV * au_energy_conversion
omega_p = omega_p_eV * au_energy_conversion
omega_es = omega_es_eV * au_energy_conversion
omega_ep = omega_ep_eV * au_energy_conversion
omega_ed = omega_ed_eV * au_energy_conversion
# Print converted energies for verification
# print(f"omega_s: {omega_s} au")
# print(f"omega_p: {omega_p} au")
# print(f"omega_es: {omega_es} au")
# print(f"omega_ep: {omega_ep} au")
# print(f"omega_ed: {omega_ed} au")


# Define x-axis positions for the levels
x_positions = {
    '1s': 0,
    '1s2p': 1,
    's': 0,
    'p': 1,
    'd': 2
}

# Define transitions (start and end points)
transitions = [
    ('1s', '1s2p', '\u03C9', 'red'),
    ('1s2p', 's', '\u03C9', 'red'),
    ('1s2p', 'd', '\u03C9', 'red'),
    ('1s', 'p', '2\u03C9', 'blue')
]

# Create the plot
fig, ax = plt.subplots()

# Plot energy levels
for level, energy in energy_levels.items():
    ax.hlines(energy, xmin=x_positions[level] - 0.2, xmax=x_positions[level] + 0.2, color='black')
    ax.text(x_positions[level] + 0.3, energy, level, verticalalignment='center')

# Plot transitions
for start, end, label, color in transitions:
    ax.annotate('', xy=(x_positions[end], energy_levels[end]), xytext=(x_positions[start], energy_levels[start]),
                arrowprops=dict(arrowstyle='<->', color=color))
    ax.text((x_positions[start] + x_positions[end]) / 2, (energy_levels[start] + energy_levels[end]) / 2, label, color=color)

ax.axhline(y=0, color='gray', linestyle='--', label='Zero Energy')

# Set plot limits and labels
ax.set_xlim(-0.5, 2.5)
ax.set_ylim(-30, 20)
ax.set_ylabel('Energy (eV)')
ax.set_xticks([0, 1, 2])
ax.set_xticklabels(['l=0', 'l=1', 'l=2'])
ax.set_yticks(list(energy_levels.values()))
ax.set_title('5-Level Helium Model')

# Show the plot
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Time array(in fs)
start_time, stop_time = -200,200  # fs
steps = 40000  # steps
t_values_SI = np.linspace(start_time, stop_time, steps)  # Time array in femtoseconds
dt_SI = t_values_SI[1]- t_values_SI[0]
print(f'Time Step is {np.round(dt_SI*1000, decimals =2)} attoseconds')
t_values = t_values_SI *au_time_conversion  # Time array in atomic units
# Time step
dt = t_values[1] - t_values[0]
# Electric Field parameters
phi_w = 0.0

tau = 50  # fs
tau_au = tau * au_time_conversion
t0 = 0 # fs  # setting t0 to a non-zero value to avoid zero limit issue
t0_au = t0 * au_time_conversion
E0_au = 0.00005
E02_au = 0.000005
omega = 21.2*au_energy_conversion

# Markers and annotations
t_min = -(tau-5)*au_time_conversion*3
t_max = (tau-5)*au_time_conversion*3
delta_T = 4*au_time_conversion

E_om = E_omega(t_values, E0_au, omega, t0_au, tau_au, phi_w)
E_field = E_om
iloc_val = np.where((t_values_SI >= 0) & (np.abs(E_field) < 1e-20))[0][0]
print(f'Index where Electric field is zero: {iloc_val}')
plt.figure()
plt.scatter(t_values_SI, E_om, label='$E_{\omega}(t)$', color='b')
plt.axvline(t_min*au_time, linestyle='--', color='gray', label='$t_{\min}$')
plt.axvline(t_max*au_time, linestyle='--', color='gray', label='$t_{\max}$')
plt.axvline((t_min - delta_T)*au_time, linestyle=':', color='red', label='$t_{\min} - \Delta T$')
plt.axvline((t_max + delta_T)*au_time, linestyle=':', color='red', label='$t_{\max} + \Delta T$')
plt.xlabel('$t (\mathrm{fs})$')
plt.ylabel('$E(t) \ (\mathrm{arb.\ unit})$')
plt.title('Electric Field with Filter Function $C(t)$')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# Time Step is 10.0 attoseconds
# Index where Electric field is zero: 33900
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Initial Hamiltonian without the field
H0 = np.array([
    [omega_s, 0, 0, 0, 0],
    [0, omega_p, 0, 0, 0],
    [0, 0, omega_es, 0, 0],
    [0, 0, 0, omega_ep, 0],
    [0, 0, 0, 0, omega_ed]
], dtype=complex)


# # Define the decay term in atomic units
# decay = au_energy_conversion*1j  #1 eV decay
# H0[2, 2] -= decay  # omega_es
# H0[3, 3] -= decay  # omega_ep
# H0[4, 4] -= decay  # omega_ed

# Hamiltonian function
# def dipole_matrix(d_ped, d_pes, d_sep, d_sp):
#     return np.array([
#         [0, d_sp, 0, d_sep, 0],
#         [d_sp, 0, d_pes, 0, d_ped],
#         [0, d_pes, 0, 0, 0],
#         [d_sep, 0, 0, 0, 0],
#         [0, d_ped, 0, 0, 0]
#     ], dtype=complex)

def dipole_matrix(d_ped, d_pes, d_sep, d_sp):
    return np.array([
        [0, d_sp, 0, d_sep, 0],
        [d_sp, 0, d_pes, 0, d_ped],
        [0, d_pes, 0, 0, 0],
        [d_sep, 0, 0, 0, 0],
        [0, d_ped, 0, 0, 0]
    ], dtype=complex)

# %%
# Define dipole matrix elements
# d_pes, d_sep, d_ped = 0.001, 0.0002, 0.0015
d_sp = 0.42
d_pes, d_sep, d_ped = 0.0015, 0.00015, 0.001

# Calculate dipole matrix element
dme = dipole_matrix(d_ped, d_pes, d_sep, d_sp)
# Diagonalize the dipole matrix
dme_eigenvalues, dme_eigenvectors = eigh(dme)
Diagonal_dme = np.diag(dme_eigenvalues)
# Reconstruct the original dipole matrix using its eigenvalues and eigenvectors
# reconstructed_dme = np.dot(dme_eigenvectors, np.dot(Diagonal_dme, dme_eigenvectors.T.conj()))

# print("Original dipole matrix (dme):")
# print(dme)
# print("\nEigenvalues of the dipole matrix:")
# print(dme_eigenvalues)
# print("\nEigenvectors of the dipole matrix:")
# print(dme_eigenvectors)
# print("\nReconstructed dipole matrix:")
# print(reconstructed_dme)

# # Check if the reconstructed matrix is close to the original matrix
# if np.allclose(dme, reconstructed_dme):
#     print("\nThe reconstructed matrix is close to the original matrix.")
# else:
#     print("\nThere is a discrepancy between the original and reconstructed matrices.")

# %%
def tdse_solver(omega_ev, phi_2w):
    omega_au = omega_ev*au_energy_conversion
    #E_om = E_omega(t_values, E0_au, omega_au, t0_au, tau_au, phi_w)
    dfs = {} # DataFrames for the all the populations at each time step
    # Initial state
    psi_0 = np.array([1, 0, 0, 0, 0], dtype=complex)
    #psi_0 = np.array([1, 0], dtype=complex)
    psi_t_list = [psi_0]
    U0_half_dt = expm(-1j * H0 * dt / 2)
    for index in range(len(t_values[1:])):
        t = t_values[index]
        #print(f"Time step {index}: t = {t} au")
        # Calculate the electric field at time t
        EF1 = E_omega(t, E0_au, omega_au, t0_au, tau_au, phi_w)
        EF2 = E_omega(t, E02_au, 2*omega_au, t0_au, tau_au, phi_2w)
        EF =EF1 + EF2
        #print(f"Electric field at t = {t} au: {EF}")
        psi_dt = psi_t_list[index]
        #print(f"psi_dt: {psi_dt}")
        psi_0_u0 = np.matmul(U0_half_dt, psi_dt)
        #print(f"psi_0_u0: {psi_0_u0}")
        psi_0_eigenbasis = np.matmul(dme_eigenvectors.T.conj(), psi_0_u0)
        u_t = expm(-1j *EF* Diagonal_dme * dt )
        #print(f"u_t: {u_t}")
        psi_t_eigenbasis = np.matmul(u_t, psi_0_eigenbasis)
        #print(f"psi_t_eigenbasis: {psi_t_eigenbasis}")
        psi_t_pre = np.matmul(dme_eigenvectors, psi_t_eigenbasis)
        #print(f"psi_t_pre: {psi_t_pre}")
        psi_t_u0 = np.matmul(U0_half_dt, psi_t_pre)
        # # Check for NaN values
        # if np.isnan(psi_t_u0).any():
        #     print(f"NaN detected at time step {index}, EF: {EF}")
        #     print(f"Intermediate values at time step {index}:")
        #     print(f"psi_0_u0: {psi_0_u0}")
        #     print(f"psi_0_eigenbasis: {psi_0_eigenbasis}")
        #     print(f"u_t: {u_t}")
        #     print(f"psi_t_eigenbasis: {psi_t_eigenbasis}")
        #     print(f"psi_t_pre: {psi_t_pre}")
        #     break
        psi_t_list.append(psi_t_u0)
    psi_t_array = np.array(psi_t_list)
    dfs[f'df_psi_{round(omega_ev,4)}_{phi_2w}'] = pd.DataFrame(psi_t_array, columns=['s', 'p', 'es', 'ep', 'ed'])
    return dfs

# %% [markdown]
# ## Test with a single omega

# %%
omega_ev = 21.2
phi_2w = np.pi/3
#print(f"Running simulation for omega = {round(omega_ev, 3)} eV")
dfs = tdse_solver(omega_ev, phi_2w)
print(f"Completed simulation for omega = {round(omega_ev, 3)} eV")
# Out:
# Completed simulation for omega = 21.2 eV

# %%
plt.figure()
#plt.plot(t_values_SI, np.abs(dfs[f'df_psi_{omega_ev}']['s'])**2, label='s')
plt.plot(t_values_SI, np.abs(dfs[f'df_psi_{omega_ev}']['p'])**2, label='p')
#plt.plot(t_values_SI, np.abs(dfs[f'df_psi_{omega_ev}']['p']), label='pa')
E_field = E_omega(t_values, E0_au, omega_ev*au_energy_conversion, t0_au, tau_au, phi_w)
#plt.scatter(t_values_SI, E_field/1e13, marker = '.', label='$E_{\omega}(t)$', color='r', alpha=0.1)
plt.plot(t_values_SI, np.abs(dfs[f'df_psi_{omega_ev}']['es']), label='es')
#plt.plot(t_values_SI, np.abs(dfs[f'df_psi_{omega_ev}']['ep'])**2, label='ep')
plt.plot(t_values_SI, np.abs(dfs[f'df_psi_{omega_ev}']['ed']), label='ed')
plt.axvline(t_min*au_time, linestyle='--', color='gray', label='$t_{\min}$')
plt.axvline(t_max*au_time, linestyle='--', color='gray', label='$t_{\max}$')
plt.axvline((t_min - delta_T)*au_time, linestyle=':', color='red', label='$t_{\min} - \Delta T$')
plt.axvline((t_max + delta_T)*au_time, linestyle=':', color='red', label='$t_{\max} + \Delta T$')
plt.xlabel('Time (fs)')
plt.ylabel('Population')
plt.title('Population Dynamics')
plt.legend(loc='best')
plt.grid(True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
#plt.plot(t_values_SI, np.abs(dfs[f'df_psi_{omega_ev}']['s'])**2, label='s')
#plt.plot(t_values_SI, np.abs(dfs[f'df_psi_{omega_ev}']['p'])**2, label='p')
plt.plot(t_values_SI, np.abs(dfs[f'df_psi_{omega_ev}']['es'])**2, label='es')
plt.plot(t_values_SI, np.abs(dfs[f'df_psi_{omega_ev}']['ep'])**2, label='ep')
plt.plot(t_values_SI, np.abs(dfs[f'df_psi_{omega_ev}']['ed'])**2, label='ed')
plt.xlabel('Time (fs)')
plt.ylabel('Population')
plt.title('Population Dynamics')
# plt.axhline(y=0, color='gray', linestyle='--', label='Zero Population')
# plt.axvline(t_min*au_time, linestyle='--', color='gray', label='$t_{\min}$')
# plt.axvline(t_max*au_time, linestyle='--', color='gray', label='$t_{\max}$')
# plt.axvline((t_min - delta_T)*au_time, linestyle=':', color='red', label='$t_{\min} - \Delta T$')
# plt.axvline((t_max + delta_T)*au_time, linestyle=':', color='red', label='$t_{\max} + \Delta T$')
plt.legend()
plt.grid()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.plot(t_values_SI, np.abs(dfs[f'df_psi_{omega_ev}']['es'])**2, label='es')
#plt.plot(t_values_SI, np.abs(dfs[f'df_psi_{omega_ev}']['ep'])**2, label='ep')
plt.plot(t_values_SI, np.abs(dfs[f'df_psi_{omega_ev}']['ed'])**2, label='ed')
plt.xlabel('Time (fs)')
plt.ylabel('Population')
# plt.axhline(y=0, color='gray', linestyle='--', label='Zero Population')
# plt.axvline(t_min*au_time, linestyle='--', color='gray', label='$t_{\min}$')
# plt.axvline(t_max*au_time, linestyle='--', color='gray', label='$t_{\max}$')
# plt.axvline((t_min - delta_T)*au_time, linestyle=':', color='red', label='$t_{\min} - \Delta T$')
# plt.axvline((t_max + delta_T)*au_time, linestyle=':', color='red', label='$t_{\max} + \Delta T$')
plt.title('Population Dynamics')
plt.legend()
plt.grid()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.close()

# %%
E_field = E_omega(t_values, E0_au, omega_ev*au_energy_conversion, t0_au, tau_au, phi_w)
plt.figure()
#plt.plot(t_values_SI,np.abs(dfs[f'df_psi_{omega_ev}']['s'])**2)
plt.plot(t_values_SI,np.abs(dfs[f'df_psi_{omega_ev}']['p'])**2)
plt.scatter(t_values_SI, E_field*1e1, label='$E_{\omega}(t)$', color='r')
#plt.plot(t_values_SI, np.abs(dfs[f'df_psi_{omega_ev}']['es'])**2, label = 'es')
#plt.plot(t_values_SI, np.abs(dfs[f'df_psi_{omega_ev}']['ep'])**2, label = 'ep')
#plt.plot(t_values_SI, np.abs(dfs[f'df_psi_{omega_ev}']['ed'])**2, label = 'ed')
plt.grid(True)
#plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Energy Scan

# %%
# Running simulations for a range of omega values
steps_eV = 0.001
omega_values = np.round(np.arange(21.1, 21.3, steps_eV), 3)

steps_phi = 0.0001
phi_values = np.round(np.arange(0, 2*np.pi, steps_phi), 7)
results_dfs = {}

# Create output directory if it does not exist
output_dir = f'simulation_results_optimisized_{tau}_{phi_2w}fs_V6.1'
os.makedirs(output_dir, exist_ok=True)

for omega_ev in omega_values:
    for phi_2w in phi_values:
        print(f"Running simulation for omega = {round(omega_ev, 3)} eV and Phi_2w = {phi_2w}")
        dfs1 = tdse_solver(omega_ev, phi_2w)
        dfs1[f'df_psi_{omega_ev}_{phi_2w}'].to_csv(os.path.join(output_dir, f'psi_t_stepseV_{steps_eV}_{round(omega_ev, 3)}_d_sep_{d_sep}_d_pes{d_pes}_d_ped_{d_ped}.csv'), index=False)
        results_dfs.update(dfs1)
        print(f"Completed simulation for omega = {round(omega_ev, 3)} eV and Phi_2w = {phi_2w}                                        ")

# Save dictionary objects
results_dfs_path = os.path.join(output_dir, f"results_dfs_stepseV_{steps_eV}_phi_{steps_phi}_d_sep_{d_sep}_d_pes{d_pes}_d_ped_{d_ped}.pkl")

pd.to_pickle(results_dfs, results_dfs_path)

print(f"All simulations completed and results saved to {output_dir}")
# Out:
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0001
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0001
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0001
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0002
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0001
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0002
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0002
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0003
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0002
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0003
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0003
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0004
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0003
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0004
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0004
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0005
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0004
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0005
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0005
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0006
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0005
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0006
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0006
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0007
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0006
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0007
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0007
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0008
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0007
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0008
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0008
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0009
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0008
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0009
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0009
# Running simulation for omega = 21.1 eV and Phi_2w = 0.001
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0009
# Running simulation for omega = 21.1 eV and Phi_2w = 0.001
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.001
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0011
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.001
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0011
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0011
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0012
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0011
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0012
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0012
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0013
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0012
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0013
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0013
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0014
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0013
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0014
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0014
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0015
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0014
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0015
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0015
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0016
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0015
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0016
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0016
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0017
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0016
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0017
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0017
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0018
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0017
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0018
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0018
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0019
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0018
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0019
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0019
# Running simulation for omega = 21.1 eV and Phi_2w = 0.002
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0019
# Running simulation for omega = 21.1 eV and Phi_2w = 0.002
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.002
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0021
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.002
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0021
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0021
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0022
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0021
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0022
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0022
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0023
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0022
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0023
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0023
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0024
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0023
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0024
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0024
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0025
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0024
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0025
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0025
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0026
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0025
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0026
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0026
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0027
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0026
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0027
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0027
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0028
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0027
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0028
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0028
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0029
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0028
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0029
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0029
# Running simulation for omega = 21.1 eV and Phi_2w = 0.003
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0029
# Running simulation for omega = 21.1 eV and Phi_2w = 0.003
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.003
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0031
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.003
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0031
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0031
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0032
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0031
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0032
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0032
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0033
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0032
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0033
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0033
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0034
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0033
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0034
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0034
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0035
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0034
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0035
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0035
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0036
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0035
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0036
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0036
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0037
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0036
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0037
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0037
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0038
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0037
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0038
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0038
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0039
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0038
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0039
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0039
# Running simulation for omega = 21.1 eV and Phi_2w = 0.004
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0039
# Running simulation for omega = 21.1 eV and Phi_2w = 0.004
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.004
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0041
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.004
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0041
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0041
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0042
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0041
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0042
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0042
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0043
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0042
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0043
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0043
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0044
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0043
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0044
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0044
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0045
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0044
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0045
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0045
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0046
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0045
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0046
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0046
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0047
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0046
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0047
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0047
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0048
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0047
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0048
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0048
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0049
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0048
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0049
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0049
# Running simulation for omega = 21.1 eV and Phi_2w = 0.005
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0049
# Running simulation for omega = 21.1 eV and Phi_2w = 0.005
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.005
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0051
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.005
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0051
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0051
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0052
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0051
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0052
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0052
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0053
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0052
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0053
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0053
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0054
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0053
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0054
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0054
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0055
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0054
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0055
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0055
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0056
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0055
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0056
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0056
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0057
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0056
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0057
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0057
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0058
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0057
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0058
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0058
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0059
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0058
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0059
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0059
# Running simulation for omega = 21.1 eV and Phi_2w = 0.006
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0059
# Running simulation for omega = 21.1 eV and Phi_2w = 0.006
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.006
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0061
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.006
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0061
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0061
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0062
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0061
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0062
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0062
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0063
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0062
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0063
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0063
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0064
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0063
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0064
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0064
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0065
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0064
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0065
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0065
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0066
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0065
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0066
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0066
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0067
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0066
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0067
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0067
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0068
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0067
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0068
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0068
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0069
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0068
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0069
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0069
# Running simulation for omega = 21.1 eV and Phi_2w = 0.007
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.0069
# Running simulation for omega = 21.1 eV and Phi_2w = 0.007
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.007
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0071
# Completed simulation for omega = 21.1 eV and Phi_2w = 0.007
# Running simulation for omega = 21.1 eV and Phi_2w = 0.0071

# %%
results_dfs[f'df_psi_{omega_ev}']['s'].iloc[iloc_val]
# Out:
# (-0.9986245267145744-0.05243142825525629j)

# %%
populations = []
populationp = []
populationes = []
populationep = []
populationed = []
for omega_ev in omega_values:
    #print(omega_ev)
    df = results_dfs[f'df_psi_{omega_ev}']
    populations.append(np.abs(df['s'].iloc[iloc_val])**2)
    populationp.append(np.abs(df['p'].iloc[iloc_val])**2)
    populationes.append(np.abs(df['es'].iloc[iloc_val])**2)
    populationep.append(np.abs(df['ep'].iloc[iloc_val])**2)
    populationed.append(np.abs(df['ed'].iloc[iloc_val])**2)

# %%
plt.figure()
#plt.plot(t_values_SI, np.abs(dfs[f'df_psi_{omega_ev}']['s'])**2, label='s')
#plt.plot(t_values_SI, np.abs(dfs[f'df_psi_{omega_ev}']['p'])**2, label='p')
plt.scatter(t_values_SI, E_field/1e11, marker = '.', label='$E_{\omega}(t)$', color='r', alpha=1.0)
#plt.plot(t_values_SI, np.abs(dfs[f'df_psi_{omega_ev}']['es'])**2, label='es')
#plt.plot(t_values_SI, np.abs(dfs[f'df_psi_{omega_ev}']['ep'])**2, label='ep')
#plt.plot(t_values_SI, np.abs(dfs[f'df_psi_{omega_ev}']['ed'])**2, label='ed')
plt.axvline(t_min*au_time, linestyle='--', color='gray', label='$t_{\min}$')
plt.axvline(t_max*au_time, linestyle='--', color='gray', label='$t_{\max}$')
plt.axvline((t_min - delta_T)*au_time, linestyle=':', color='red', label='$t_{\min} - \Delta T$')
plt.axvline((t_max + delta_T)*au_time, linestyle=':', color='red', label='$t_{\max} + \Delta T$')
plt.xlabel('Time (fs)')
plt.ylabel('Population')
plt.title('Population Dynamics')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#populations = np.array(populations).astype(int)
plt.figure()
#plt.scatter(omega_values, populations, marker='x', label='s' , color='red')
#plt.scatter(omega_values, populationp, marker='.', label='p', color='blue')
plt.scatter(omega_values, populationes, marker='x', label='es', color='green')
plt.scatter(omega_values, populationep, marker='.', label='ep', color='orange')
plt.plot(omega_values, populationed, label='ed', marker='o', color='purple')
plt.title('Population of states')
plt.xlabel('Omega (eV)')
plt.ylabel('Population')
#plt.legend(['s', 'p', 'es', 'pes', 'ed'])
#plt.legend(['es', 'ep', 'ed'])
plt.legend()
#plt.xlim(21.09, 21.2)
#plt.ylim(0, 3e-17)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#populations = np.array(populations).astype(int)
plt.figure()
#plt.scatter(omega_values, populations, marker='x', label='s' , color='red')
#plt.scatter(omega_values, populationp, marker='.', label='p', color='blue')
#plt.plot(omega_values, populationes, marker='x', label='es', color='green')
plt.plot(omega_values, populationep, marker='.', label='ep', color='orange')
#plt.plot(omega_values, populationed, label='ed', marker='o', color='purple')
#plt.axvline(x=Ecooper, color='brown', linestyle='--', label='Cooper Minimum')
#plt.axvline(x=Eres, color='black', linestyle='--', label='Resonance')
plt.title('Population of states')
plt.xlabel('Omega (eV)')
plt.ylabel('Population')
plt.legend()
#plt.xlim(21.09, 21.35)
#plt.ylim(0, 3e-17)
plt.show()
#plt.close()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Compare with Chris Green values

# %%
data=np.loadtxt('c_phi_spd_40_45 (no phase jumps).dat',skiprows=1)
data[1294:2874,2]=-data[1294:2874,2]
data[1294:1564,6]=-data[1294:1564,6]

# %%
Ew= E0_au
E2w= E02_au

DeltaPhi=0

omega=data[:,1]/2
c0=data[:,2]*Ew**2
c1=data[:,4]*E2w
c2=data[:,6]*Ew**2
phi0=data[:,3]
phi1=data[:,5]
phi2=data[:,7]

Wtot=c0**2 + c1**2 + c2**2
beta1=(2*np.sqrt(3)*c0*c1*np.cos(DeltaPhi-(phi0-phi1))
      +(4/np.sqrt(3))*c1*c2*np.cos(DeltaPhi-(phi2-phi1)))/Wtot
beta2=(2*c1**2 + (10/7)*c2**2 + 2*np.sqrt(5)*c0*c2*np.cos(phi2-phi0))/Wtot
beta3=((6/np.sqrt(3))*c1*c2*np.cos(DeltaPhi-(phi2-phi1)))/Wtot
beta4=((18/7)*c2**2)/Wtot

Ecooper=(-c2[1563]/(c2[1564]-c2[1563]))*(omega[1564]-omega[1563])+omega[1563]
Eres=21.216174

# %%
# %matplotlib inline
plt.scatter(omega, c0, marker='x', label='es', color='green')
plt.scatter(omega, c1, marker='.', label='ep', color='orange')
plt.scatter(omega, c2, label='ed', marker='o', color='purple')
plt.title('Population of states at 1000 fs')
plt.xlabel('Omega (eV)')
plt.ylabel('Population')
#plt.legend(['s', 'p', 'es', 'pes', 'ed'])
#plt.legend(['es', 'ep', 'ed'])
plt.legend()
plt.xlim(21.175, 21.2)
plt.show()

# %%
# %matplotlib widget

# %%
fig,ax = plt.subplots()
ax.plot(omega,c0,'.',label='s wave',markersize=2)
ax.plot(omega,c1,'.',label='p wave',markersize=2)
ax.plot(omega,c2,'.',label='d wave',markersize=2)
ax.axvline(x=Ecooper,color='black')
ax.axvline(x=Eres,color='black',ls='dashdot')
ax.axhline(y=0,color='black',ls='--')
#plt.yscale('symlog')
ax.set_xlabel(r'$\omega$ Photon energy (eV)')
ax.set_ylabel('Amplitude (a.u.)')
#ax.set_xlim(21.2161,21.2162)
#ax.set_ylim(-0.02,0.02)
plt.legend()
ax2=ax.secondary_xaxis('top',functions=(lambda x:x*2, lambda x:x/2))
ax2.set_xlabel(r'2$\omega$ Photon energy (eV)')
plt.show()
#plt.close()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
